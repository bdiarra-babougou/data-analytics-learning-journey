# %% [markdown]
# ## 🧠 Projec 2: Text Analysis with Python
#
# ## Scenario
#
# Imagine you are working as a data analyst for a company that collects thousands of customer reviews every day. Reading each review manually is time-consuming and inefficient. Instead, you can use Python to automatically process the text and extract meaningful insights.
#
# In this project, you will build a simple text analysis tool that preprocesses textual data, counts the frequency of words, and searches for the occurrence of a specific keyword. The techniques used in this exercise form the foundation of many real-world Natural Language Processing (NLP) applications such as customer sentiment analysis, product review mining, and social media analytics.
#
# ---
#
# # 📖 What is Text Analysis?
#
# Text analysis, also known as **text mining** or **text analytics**, is the process of transforming unstructured text into meaningful information. By applying computational techniques, large collections of text can be summarized, organized, and analyzed to uncover useful patterns, trends, and insights.
#
# In this project, we will focus on one of the most fundamental text analysis techniques: **word frequency analysis**.
#
# ---
#
# # 🎯 Project Objectives
#
# By the end of this project, you will be able to:
#
# * Preprocess text by converting it to lowercase.
# * Remove punctuation to standardize textual data.
# * Count the frequency of every unique word in a document.
# * Determine how many times a specific word appears in a text.
# * Apply object-oriented programming by creating a reusable Python class for text analysis.
#
# ---
#
# # 🛠 Technologies and Python Concepts
#
# This project introduces several fundamental Python concepts, including:
#
# * **Strings** – storing and manipulating textual data.
# * **Lists** – splitting text into individual words.
# * **Dictionaries** – storing word frequencies.
# * **Classes and Objects** – building a reusable text analysis tool.
# * **Pandas
#
# ---
#
# # 🌍 Project Scenario
#
# Suppose you have collected customer feedback for a product. Your objective is to extract useful information from these reviews instead of reading them one by one.
#
# To achieve this, your text analysis tool will perform three essential tasks.
#
# ### **Task 1 – Text Preprocessing**
#
# Before analyzing the data, the text must be standardized. This involves converting all characters to lowercase and removing punctuation marks. Doing so ensures that words such as **"Reliable"**, **"RELIABLE"**, and **"reliable"** are treated as the same word during analysis.
#
# ---
#
# ### **Task 2 – Word Frequency Analysis**
#
# Once the text has been cleaned, the program will calculate the frequency of every unique word. This allows us to identify the most frequently mentioned terms, helping reveal common topics, recurring issues, or popular product features.
#
# ---
#
# ### **Task 3 – Keyword Frequency Analysis**
#
# Sometimes we are interested in monitoring a specific keyword rather than the entire vocabulary. For example, if we want to evaluate product reliability, we can determine how many times the word **"reliable"** appears throughout the customer reviews.
#
# This targeted analysis provides deeper insights into customer opinions regarding a particular feature or aspect of the product.
#
# ---
#
# # 📌 Project Workflow
#
# The project is divided into two parts. In the first part, we build our text analysis tool. In the second part, we use that tool to analyze text and generate results.
#
# ---

# %% [markdown]
# ## Part A – Building the Text Analyzer
#
# In this section, we will create the TextAnalyzer class and implement the methods required to perform text analysis.
#
# # Note: No output will be produced in this section because we are only defining the class and its methods.

# %% [markdown]
# ## Step 1 – Define or load the Input Text
#
# Create a variable containing the sample text that will be analyzed throughout the project.
#
# For demonstration purposes, we create a sample customer review and save it as a text file. In real-world applications, this data would typically come from product reviews, surveys, or social media platforms.

# %%
# Open and read the sample text
with open("customer_review.txt", "r", encoding="utf-8") as file:
    review = file.read()

# Display the first 500 characters
print(review[:500])
# Out:
# I purchased this project management software after reading several positive reviews and watching the promotional videos on the company's website. Based on the advertised features, I expected a reliable, intuitive, and efficient tool that would help my team organize tasks, manage deadlines, and improve collaboration. Unfortunately, my experience has been the exact opposite, and after using the software for several weeks, I am extremely disappointed with both the product and the overall customer

# %% [markdown]
# ## Step 2 – Create the TextAnalyzer Class
#
# Create a class named TextAnalyzer.
#
# Inside the constructor (__init__), accept the input text as a parameter and prepare it for further analysis.

# %%
# Please do not run this code cell as it is incomplete and will produce an error.

# Let's create a class called TextAnalyzer to analyze text.
#class TextAnalyzer(object):
    # The __init__ method initializes the class with a 'text' parameter.
    # We will store the provided 'text' as an instance variable.
    #def __init__(self, text):

# %% [markdown]
# ## Step 3 – Preprocess the Text
#
# Update the constructor to clean and standardize the input text by:
#
# converting all characters to lowercase,
# removing punctuation marks,
# storing the cleaned text in a new attribute named fmtText.
#
# This preprocessing step ensures consistent and reliable analysis.

# %%
# Press Shift+Enter to run the code.
class TextAnalzer(object):
    
    def __init__ (self, text):
        # remove punctuation
        formattedText = text.replace('.','').replace('!','').replace('?','').replace(',','')
        
        # make text lowercase
        formattedText = formattedText.lower()
        
        self.fmtText = formattedText

# %% [markdown]
# ## Step 4 – Count the Frequency of All Words
#
# Implement the freqAll() method to calculate the frequency of every unique word in the text.
#
# The method should:
#
#     1. Split the cleaned text into individual words.
#     2. Create a dictionary to store word frequencies.
#     3. Count the occurrences of each unique word.
#     4. Return the completed frequency dictionary.

# %%
#Press shift+Enter to run the code
class TextAnalyzer(object):
    
    def __init__ (self, text):
        # remove punctuation
        formattedText = text.replace('.','').replace('!','').replace('?','').replace(',','')
        
        # make text lowercase
        formattedText = formattedText.lower()
        
        self.fmtText = formattedText
        
    def freqAll(self):        
        # split text into words
        wordList = self.fmtText.split(' ')
        
        # Create dictionary
        freqMap = {}
        for word in set(wordList): # use set to remove duplicates in list
            freqMap[word] = wordList.count(word)
        
        return freqMap

# %%
# Create an instance of the class
analyzer = TextAnalyzer(review)

# Get frequency dictionary
frequency = analyzer.freqAll()

# Print results
print(frequency)
# Out:
# {'company': 1, 'taking': 1, 'poor': 1, 'several': 11, 'which': 1, 'feels': 1, 'actually': 2, 'made': 4, 'unless': 1, 'menus': 1, 'succeed': 1, 'management': 2, 'support': 7, 'frequently': 2, 'when': 3, 'helping': 1, 'behind': 2, 'unfortunately': 3, 'continuous': 1, 'errors': 2, 'been': 10, 'regarding': 1, 'disappointing': 2, 'especially': 1, 'of': 15, 'provided': 1, 'a': 11, 'weeks': 2, 'members': 1, 'workflow': 1, 'tools\n\nsecurity': 1, 'improve': 2, 'customer': 4, 'takes': 1, 'between': 1, 'solutions': 1, 'me': 1, 'should': 2, 'issue': 1, 'unrelated': 1, 'reason': 1, 'projects': 3, 'unnecessarily': 1, 'regularly': 1, 'times': 4, 'improved': 1, 'forcing': 2, 'few': 1, 'to': 23, 'cost': 1, 'searching': 1, 'process': 1, 'with': 2, 'price': 1, 'some': 2, 'formatting': 1, 'confusion': 1, 'occasion': 2, 'hiding': 1, 'because': 1, 'users': 3, 'updates': 3, 'template': 1, 'current': 1, 'testing\n\nconsidering': 1, 'seconds': 1, 'confusing': 1, 'user': 3, 'produces': 1, 'indicating': 1, 'o
# ...

# %% [markdown]
# ## Step 5 - Count the Frequency of a Specific Word
#
# Implement the freqOf(word) method.
#
# This method should:
#
#     1. Accept a word as an argument.
#     2. Search for the word in the frequency dictionary.
#     3. Return the number of times that word appears in the text.

# %%
#Press Shift+Enter to run the code
class TextAnalyzer(object):
    
    def __init__ (self, text):
        # remove punctuation
        formattedText = text.replace('.','').replace('!','').replace('?','').replace(',','')
        
        # make text lowercase
        formattedText = formattedText.lower()
        
        self.fmtText = formattedText
        
    def freqAll(self):        
        # split text into words
        wordList = self.fmtText.split(' ')
        
        # Create dictionary
        freqMap = {}
        for word in set(wordList): # use set to remove duplicates in list
            freqMap[word] = wordList.count(word)
        
        return freqMap
    
    def freqOf(self,word):
        # get frequency map
        freqDict = self.freqAll()
        
        if word in freqDict:
            return freqDict[word]
        else:
            return 0

# %% [markdown]
# ## Part B – Using the Text Analyzer
#
# With the class complete, we can now use it to analyze text and generate meaningful results.

# %% [markdown]
# ## Step 1 – Create an Instance of the Class
#
# Instantiate the TextAnalyzer class by passing the sample text to the constructor.

# %%
# type your code here
analyzed = TextAnalyzer(review)

# %% [markdown]
# ## Step 2 – Preprocess the Text
#
# Call the method responsible for formatting the text and verify that the text has been converted to lowercase and cleaned.

# %%
# Press Shift+Enter to run the code.
print("Formatted Text:", analyzed.fmtText)
# Out:
# Formatted Text:
# i purchased this project management software after reading several positive reviews and watching the promotional videos on the company's website based on the advertised features i expected a reliable intuitive and efficient tool that would help my team organize tasks manage deadlines and improve collaboration unfortunately my experience has been the exact opposite and after using the software for several weeks i am extremely disappointed with both the product and the overall customer experience
#
# ...

# %% [markdown]
# ## Step 3 – Analyze Word Frequencies
#
# Call the freqAll() method to display the frequency of every unique word in the text.

# %%
# Press Shift+Enter to run the code.
freqMap = analyzed.freqAll()
print(freqMap)
# Out:
# {'company': 1, 'taking': 1, 'poor': 1, 'several': 11, 'which': 1, 'feels': 1, 'actually': 2, 'made': 4, 'unless': 1, 'menus': 1, 'succeed': 1, 'management': 2, 'support': 7, 'frequently': 2, 'when': 3, 'helping': 1, 'behind': 2, 'unfortunately': 3, 'continuous': 1, 'errors': 2, 'been': 10, 'regarding': 1, 'disappointing': 2, 'especially': 1, 'of': 15, 'provided': 1, 'a': 11, 'weeks': 2, 'members': 1, 'workflow': 1, 'tools\n\nsecurity': 1, 'improve': 2, 'customer': 4, 'takes': 1, 'between': 1, 'solutions': 1, 'me': 1, 'should': 2, 'issue': 1, 'unrelated': 1, 'reason': 1, 'projects': 3, 'unnecessarily': 1, 'regularly': 1, 'times': 4, 'improved': 1, 'forcing': 2, 'few': 1, 'to': 23, 'cost': 1, 'searching': 1, 'process': 1, 'with': 2, 'price': 1, 'some': 2, 'formatting': 1, 'confusion': 1, 'occasion': 2, 'hiding': 1, 'because': 1, 'users': 3, 'updates': 3, 'template': 1, 'current': 1, 'testing\n\nconsidering': 1, 'seconds': 1, 'confusing': 1, 'user': 3, 'produces': 1, 'indicating': 1, 'o
# ...

# %% [markdown]
# ## Step 4 - Display the top words instead of the whole dictionary

# %%
sorted_freq = sorted(frequency.items(),
                     key=lambda item: item[1],
                     reverse=True)

for word, count in sorted_freq[:10]:
    print(f"{word:<15} {count}")
# Out:
# the             55
# and             27
# to              23
# of              15
# i               15
# several         11
# a               11
# software        11
# been            10
# that            10

# %% [markdown]
# ## Step 5 – Analyze a Specific Keyword
#
# Call the freqOf() method to determine how many times the word "performance" appears in the text.
#
# Finally, print the results and interpret the output.**

# %%
# Analyzing a specific word
word = "performance"
frequency = analyzed.freqOf(word)
print("The word",word,"appears",frequency,"times.")
# Out:
# The word performance appears 4 times.

# %% [markdown]
# ## Step 6 - Display the results as a table

# %%
import pandas as pd

frequency = analyzer.freqAll()

df = pd.DataFrame(
    frequency.items(),
    columns=["Word", "Frequency"]
)

df.sort_values(
    by="Frequency",
    ascending=False,
    inplace=True
)

df.head(15)
# Out:
#          Word  Frequency
# 163       the         55
# 346       and         27
# 48         to         23
# 356         i         15
# 24         of         15
# 26          a         11
# 3     several         11
# 78   software         11
# 20       been         10
# 450      that         10
# 304       has          8
# 75       this          8
# 12    support          7
# 348        in          7
# 211      were          7

# %% [markdown]
# ## 🎉 Conclusion
#
# In this project, you developed a reusable Python class capable of performing basic text analysis. By combining string manipulation, dictionaries, and object-oriented programming, you built a simple yet powerful tool for extracting information from unstructured text.

# %% [markdown]
# ## 👨‍💻 Author
#
# Bourema Diarra
#
# Python Data Analysis Project
